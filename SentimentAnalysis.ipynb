# %%
import pandas as pd

df = pd.read_csv("FulDoc_Final.csv")
# dataset = df.Column1.tolist()
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_13548\1302189025.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df.columns
# Out:
# Index(['Document', 'Topic', 'Name', 'Representation', 'Representative_Docs',
#        'Top_n_words', 'Probability', 'Representative_document'],
#       dtype='object')

# %%
df.Topic
# Out:
# 0         7
# 1         0
# 2        13
# 3         7
# 4         2
#          ..
# 10254    14
# 10255     1
# 10256     9
# 10257     2
# 10258     7
# Name: Topic, Length: 10259, dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame containing the CSV data

# Group the DataFrame by the 'Topic' column
grouped = df.groupby('Topic')

# Iterate over each group
for topic, group in grouped:
    # Access documents within the group
    documents = group[['Document', 'Topic']].copy()
    
    # Save the group to a CSV file
    file_name = f"topic_{topic}_documents.csv"
    documents.to_csv(file_name, index=False)
    print(f"Saved documents for Topic {topic} to {file_name}")
# Out:
# Saved documents for Topic -1 to topic_-1_documents.csv
# Saved documents for Topic 0 to topic_0_documents.csv
# Saved documents for Topic 1 to topic_1_documents.csv
# Saved documents for Topic 2 to topic_2_documents.csv
# Saved documents for Topic 3 to topic_3_documents.csv
# Saved documents for Topic 4 to topic_4_documents.csv
# Saved documents for Topic 5 to topic_5_documents.csv
# Saved documents for Topic 6 to topic_6_documents.csv
# Saved documents for Topic 7 to topic_7_documents.csv
# Saved documents for Topic 8 to topic_8_documents.csv
# Saved documents for Topic 9 to topic_9_documents.csv
# Saved documents for Topic 10 to topic_10_documents.csv
# Saved documents for Topic 11 to topic_11_documents.csv
# Saved documents for Topic 12 to topic_12_documents.csv
# Saved documents for Topic 13 to topic_13_documents.csv
# Saved documents for Topic 14 to topic_14_documents.csv
# Saved documents for Topic 15 to topic_15_documents.csv
# Saved documents for Topic 16 to topic_16_documents.csv
# Saved documents for Topic 17 to topic_17_documents.csv
# Saved documents for Topic 18 to topic_18_documents.csv
# Saved documents for Topic 19 to topic_19_documents.csv

# %%
import pandas as pd

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

# Loop through topics 0 to 19
for topic in range(20):
    # Load the CSV file for the current topic
    file_name = f"topic_{topic}_documents.csv"
    df_topic = pd.read_csv(file_name)
    
    # Append the current topic's data to the combined DataFrame
    combined_df = pd.concat([combined_df, df_topic])

# Save the combined DataFrame to a single CSV file
combined_file_name = "combinedTopics_documents.csv"
combined_df.to_csv(combined_file_name, index=False)
print(f"Combined documents saved to {combined_file_name}")
# Out:
# Combined documents saved to combinedTopics_documents.csv

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
df = pd.read_csv("combinedTopics_documents.csv")
dataset = df.Document.tolist()

def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# res = {}
# for i, row in tqdm(dataset.iterrows(), total=len(dataset)):
#     try:
#         text = row['Text']
#         myid = row['Id']
#         vader_result = sia.polarity_scores(text)
#         vader_result_rename = {}
#         for key, value in vader_result.items():
#             vader_result_rename[f"vader_{key}"] = value
#         roberta_result = polarity_scores_roberta(text)
#         both = {**vader_result_rename, **roberta_result}
#         res[myid] = both
#     except RuntimeError:
#         print(f'Broke for id {myid}')

res = {}
for text in dataset:
    result = polarity_scores_roberta(text)
    res[text] = result

# %% [raw]
# len(res)

# %%
df = pd.read_csv("topic_18_documents.csv")
dataset = df.Document.tolist()

def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    
    scores = softmax(scores)

    max_score = max(scores[0],scores[1],scores[2])

    if max_score == scores[0]:
      scores_dict = {
            'neg' : scores[0],
        }
    elif max_score == scores[1]:
     scores_dict = {
            'neu' : scores[1]
        }
    elif max_score == scores[2]:
     scores_dict = {
            'pos' : scores[2]
        }
    # scores_dict = {
    #     'roberta_neg' : scores[0],
    #     'roberta_neu' : scores[1],
    #     'roberta_pos' : scores[2]
    # }
    return scores_dict
res = {}
for i,text in enumerate(dataset):
    result = polarity_scores_roberta(text)
    res[i] = result
# result = polarity_scores_roberta(df['Document'][1])

# %%
result
# Out:
# {'roberta_neg': 0.86680555,
#  'roberta_neu': 0.12324756,
#  'roberta_pos': 0.009946926}

# %%
res
# Out:
# {0: {'neu': 0.6329646},
#  1: {'neg': 0.86680555},
#  2: {'neg': 0.71683925},
#  3: {'neg': 0.6208767},
#  4: {'pos': 0.8482429},
#  5: {'neu': 0.65453297},
#  6: {'neu': 0.70108557},
#  7: {'neu': 0.6964784},
#  8: {'neg': 0.7609605},
#  9: {'neu': 0.72194237},
#  10: {'neu': 0.5728339},
#  11: {'neg': 0.5457091},
#  12: {'pos': 0.854527},
#  13: {'neu': 0.60297835},
#  14: {'neu': 0.61217916},
#  15: {'neu': 0.6234418},
#  16: {'neu': 0.6076151},
#  17: {'neu': 0.5583663},
#  18: {'neu': 0.6779705},
#  19: {'neu': 0.8630972},
#  20: {'neg': 0.8854976},
#  21: {'neg': 0.6808572},
#  22: {'neu': 0.851581},
#  23: {'neu': 0.8216753},
#  24: {'neu': 0.85125804},
#  25: {'neu': 0.8904047},
#  26: {'neu': 0.60297835},
#  27: {'pos': 0.7101594},
#  28: {'neu': 0.75732356},
#  29: {'neg': 0.58218133},
#  30: {'neu': 0.7519675},
#  31: {'neu': 0.6481365},
#  32: {'neu': 0.77835995},
#  33: {'neu': 0.5880742},
#  34: {'neu': 0.51575744},
#  35: {'neu': 0.57576126},
#  36: {'neu': 0.87080866},
#  37: {'neg': 0.52155524},
#  38: {'neu': 0.80523753},
#  39: {'neu': 0.53223795},
#  40: {'neu': 0.49955907},
#  41: {'neu': 0.5726594},
#  42: {'neg': 0.5245836},
#  43: {'neu': 0.8839062},
#  44: {'neu': 0.75284094},
#  45: {'neu': 0.7089413},
#  46: {'neu': 0.71416616},
#  47: {'neu': 0.7514086},
#  48: {'neu': 0.61910814},
#  49: {'neu': 0.7099346},
#  50: {'neu': 0.4752075},
#  51: {'pos': 0.55150205},
#  52: {'neu': 0.67321557},
#  53: {'neu': 0.8920645},
#  54: {'pos': 0.96277386},
#  55: {'pos': 0.628634},
#  56: {'neg': 0.6162712},
#  57: {'neg': 0.8762957},
#  58: {'neg': 0.49544856},
#  59: {'neu': 0.73121583},
#  60: {'neu': 0.7483398},
#  61: {'neg': 0.72514564},
#  62: {'neg': 0.67065424},
#  63: {'neg': 0.63941056},
#  64: {'neu': 0.79244685},
#  65: {'neu': 0.5397286},
#  66: {'neu': 0.5575383},
#  67: {'pos': 0.89072275},
#  68: {'neu': 0.6298321},
#  69: {'neu': 0.47883895},
#  70: {'pos': 0.5757035},
#  71: {'neg': 0.64778674},
#  72: {'neu': 0.8720761},
#  73: {'neu': 0.565465},
#  74: {'neg': 0.6379486},
#  75: {'neu': 0.54716545},
#  76: {'neg': 0.8890345},
#  77: {'neg': 0.73995817},
#  78: {'pos': 0.57633024},
#  79: {'neu': 0.76023096},
#  80: {'neu': 0.6656968},
#  81: {'neg': 0.8982339},
#  82: {'neu': 0.6832672},
#  83: {'neg': 0.8072771},
#  84: {'neg': 0.9430763},
#  85: {'neu': 0.74041116},
#  86: {'neg': 0.6854475},
#  87: {'neu': 0.6367504},
#  88: {'neu': 0.5805682},
#  89: {'neu': 0.55985284},
#  90: {'neu': 0.5396085},
#  91: {'neu': 0.67062503},
#  92: {'neg': 0.89188355},
#  93: {'neu': 0.7377951},
#  94: {'neu': 0.7429185},
#  95: {'neu': 0.7618155},
#  96: {'neu': 0.85923654},
#  97: {'neu': 0.5394892},
#  98: {'neu': 0.7261369},
#  99: {'neu': 0.70705837},
#  100: {'neg': 0.97896534},
#  101: {'neu': 0.6086061},
#  102: {'neu': 0.55857795},
#  103: {'neg': 0.8985314},
#  104: {'neu': 0.6437286},
#  105: {'neu': 0.88055617},
#  106: {'neu': 0.75145715},
#  107: {'neu': 0.6728143},
#  108: {'neu': 0.81820893},
#  109: {'neu': 0.7584024},
#  110: {'neu': 0.5242721},
#  111: {'neu': 0.59571075},
#  112: {'neu': 0.52636683},
#  113: {'neu': 0.628737},
#  114: {'neu': 0.5055777},
#  115: {'neu': 0.8229766},
#  116: {'neu': 0.8403981},
#  117: {'pos': 0.60538954},
#  118: {'neg': 0.5029629},
#  119: {'neu': 0.747034},
#  120: {'neu': 0.8150333},
#  121: {'neg': 0.8585313},
#  122: {'pos': 0.64415324},
#  123: {'neu': 0.79972285},
#  124: {'neu': 0.8634446},
#  125: {'neu': 0.79911804},
#  126: {'neu': 0.6685542},
#  127: {'neu': 0.61551064},
#  128: {'neu': 0.8528769},
#  129: {'neu': 0.7752984},
#  130: {'neu': 0.65876603},
#  131: {'neu': 0.7906581},
#  132: {'neu': 0.88906705},
#  133: {'neu': 0.7953865},
#  134: {'neu': 0.6206551},
#  135: {'neu': 0.700954},
#  136: {'neu': 0.8492714},
#  137: {'neu': 0.6337869},
#  138: {'neu': 0.74176455},
#  139: {'neu': 0.59524685},
#  140: {'neu': 0.8446957},
#  141: {'neg': 0.5677804},
#  142: {'pos': 0.6877404},
#  143: {'neu': 0.7467106},
#  144: {'neg': 0.8159737},
#  145: {'neu': 0.62706065},
#  146: {'neg': 0.53400826},
#  147: {'neu': 0.714126},
#  148: {'neu': 0.84497404},
#  149: {'neu': 0.47564045},
#  150: {'neu': 0.51960254},
#  151: {'neu': 0.78622884},
#  152: {'pos': 0.6816964},
#  153: {'neg': 0.4396161},
#  154: {'neu': 0.77757025},
#  155: {'neg': 0.6119257},
#  156: {'neu': 0.5684501},
#  157: {'neu': 0.6242087},
#  158: {'neu': 0.68861985},
#  159: {'neg': 0.668068},
#  160: {'neu': 0.7263902},
#  161: {'pos': 0.91482073},
#  162: {'pos': 0.89901537},
#  163: {'neu': 0.82072794},
#  164: {'neu': 0.6129177},
#  165: {'neu': 0.7625606},
#  166: {'neu': 0.5835362},
#  167: {'neu': 0.8149031},
#  168: {'neg': 0.58949405},
#  169: {'neu': 0.48812446},
#  170: {'neg': 0.6572365},
#  171: {'neu': 0.6047431},
#  172: {'neu': 0.60621023},
#  173: {'neu': 0.53806573},
#  174: {'neu': 0.58656806}}

# %%
df = pd.read_csv("topic_18_documents.csv")
dataset = df.Document.tolist()

def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    
    scores = softmax(scores)

    max_score = max(scores[0],scores[1],scores[2])

    # if max_score == scores[0]:
    #   scores_dict = {
    #         'neg' : scores[0],
    #     }
    # elif max_score == scores[1]:
    #  scores_dict = {
    #         'neu' : scores[1]
    #     }
    # elif max_score == scores[2]:
    #  scores_dict = {
    #         'pos' : scores[2]
    #     }
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict
res = {}
for i,text in enumerate(dataset):
    result = polarity_scores_roberta(text)
    res[i] = result
# result = polarity_scores_roberta(df['Document'][1])

# %%
res
# Out:
# {0: {'roberta_neg': 0.16356009,
#   'roberta_neu': 0.6329646,
#   'roberta_pos': 0.2034753},
#  1: {'roberta_neg': 0.86680555,
#   'roberta_neu': 0.12324751,
#   'roberta_pos': 0.009946915},
#  2: {'roberta_neg': 0.71683925,
#   'roberta_neu': 0.24226356,
#   'roberta_pos': 0.04089722},
#  3: {'roberta_neg': 0.6208767,
#   'roberta_neu': 0.35221022,
#   'roberta_pos': 0.026913071},
#  4: {'roberta_neg': 0.006929999,
#   'roberta_neu': 0.14482714,
#   'roberta_pos': 0.8482429},
#  5: {'roberta_neg': 0.22594637,
#   'roberta_neu': 0.65453297,
#   'roberta_pos': 0.1195206},
#  6: {'roberta_neg': 0.046836004,
#   'roberta_neu': 0.70108557,
#   'roberta_pos': 0.2520784},
#  7: {'roberta_neg': 0.08876085,
#   'roberta_neu': 0.6964784,
#   'roberta_pos': 0.21476074},
#  8: {'roberta_neg': 0.7609605,
#   'roberta_neu': 0.22054705,
#   'roberta_pos': 0.018492408},
#  9: {'roberta_neg': 0.2359209,
#   'roberta_neu': 0.72194237,
#   'roberta_pos': 0.042136777},
#  10: {'roberta_neg': 0.38713324,
#   'roberta_neu': 0.5728339,
#   'roberta_pos': 0.040032875},
#  11: {'roberta_neg': 0.5457091,
#   'roberta_neu': 0.41064966,
#   'roberta_pos': 0.043641344},
#  12: {'roberta_neg': 0.008445351,
#   'roberta_neu': 0.13702767,
#   'roberta_pos': 0.854527},
#  13: {'roberta_neg': 0.28311706,
#   'roberta_neu': 0.60297835,
#   'roberta_pos': 0.113904595},
#  14: {'roberta_neg': 0.28054592,
#   'roberta_neu': 0.61217916,
#   'roberta_pos': 0.10727491},
#  15: {'roberta_neg': 0.0031782538,
#   'roberta_neu': 0.6234418,
#   'roberta_pos': 0.37337992},
#  16: {'roberta_neg': 0.28033325,
#   'roberta_neu': 0.6076151,
#   'roberta_pos': 0.11205162},
#  17: {'roberta_neg': 0.3509208,
#   'roberta_neu': 0.5583663,
#   'roberta_pos': 0.09071284},
#  18: {'roberta_neg': 0.291789,
#   'roberta_neu': 0.6779705,
#   'roberta_pos': 0.030240448},
#  19: {'roberta_neg': 0.11148736,
#   'roberta_neu': 0.8630972,
#   'roberta_pos': 0.025415465},
#  20: {'roberta_neg': 0.8854976,
#   'roberta_neu': 0.09620097,
#   'roberta_pos': 0.018301338},
#  21: {'roberta_neg': 0.6808572,
#   'roberta_neu': 0.27953425,
#   'roberta_pos': 0.03960854},
#  22: {'roberta_neg': 0.087740555,
#   'roberta_neu': 0.851581,
#   'roberta_pos': 0.060678434},
#  23: {'roberta_neg': 0.073284656,
#   'roberta_neu': 0.8216753,
#   'roberta_pos': 0.1050401},
#  24: {'roberta_neg': 0.09436506,
#   'roberta_neu': 0.85125804,
#   'roberta_pos': 0.054376926},
#  25: {'roberta_neg': 0.042096037,
#   'roberta_neu': 0.8904047,
#   'roberta_pos': 0.06749921},
#  26: {'roberta_neg': 0.28311706,
#   'roberta_neu': 0.60297835,
#   'roberta_pos': 0.113904595},
#  27: {'roberta_neg': 0.022376535,
#   'roberta_neu': 0.2674641,
#   'roberta_pos': 0.7101594},
#  28: {'roberta_neg': 0.15302229,
#   'roberta_neu': 0.75732356,
#   'roberta_pos': 0.0896542},
#  29: {'roberta_neg': 0.58218133,
#   'roberta_neu': 0.363558,
#   'roberta_pos': 0.054260727},
#  30: {'roberta_neg': 0.171238,
#   'roberta_neu': 0.7519675,
#   'roberta_pos': 0.07679458},
#  31: {'roberta_neg': 0.13040633,
#   'roberta_neu': 0.6481365,
#   'roberta_pos': 0.22145717},
#  32: {'roberta_neg': 0.15355694,
#   'roberta_neu': 0.77835995,
#   'roberta_pos': 0.06808314},
#  33: {'roberta_neg': 0.34602773,
#   'roberta_neu': 0.5880742,
#   'roberta_pos': 0.06589808},
#  34: {'roberta_neg': 0.4558802,
#   'roberta_neu': 0.51575744,
#   'roberta_pos': 0.028362384},
#  35: {'roberta_neg': 0.31647292,
#   'roberta_neu': 0.57576126,
#   'roberta_pos': 0.10776579},
#  36: {'roberta_neg': 0.060941406,
#   'roberta_neu': 0.87080866,
#   'roberta_pos': 0.06824989},
#  37: {'roberta_neg': 0.52155524,
#   'roberta_neu': 0.36298522,
#   'roberta_pos': 0.11545952},
#  38: {'roberta_neg': 0.07015528,
#   'roberta_neu': 0.80523753,
#   'roberta_pos': 0.12460711},
#  39: {'roberta_neg': 0.0688915,
#   'roberta_neu': 0.53223795,
#   'roberta_pos': 0.39887047},
#  40: {'roberta_neg': 0.43868822,
#   'roberta_neu': 0.49955907,
#   'roberta_pos': 0.06175267},
#  41: {'roberta_neg': 0.38513517,
#   'roberta_neu': 0.5726594,
#   'roberta_pos': 0.042205445},
#  42: {'roberta_neg': 0.5245836,
#   'roberta_neu': 0.45933104,
#   'roberta_pos': 0.016085353},
#  43: {'roberta_neg': 0.052306313,
#   'roberta_neu': 0.8839062,
#   'roberta_pos': 0.06378748},
#  44: {'roberta_neg': 0.115846604,
#   'roberta_neu': 0.75284094,
#   'roberta_pos': 0.1313124},
#  45: {'roberta_neg': 0.24211888,
#   'roberta_neu': 0.7089413,
#   'roberta_pos': 0.048939854},
#  46: {'roberta_neg': 0.17475677,
#   'roberta_neu': 0.71416616,
#   'roberta_pos': 0.11107708},
#  47: {'roberta_neg': 0.017392805,
#   'roberta_neu': 0.7514086,
#   'roberta_pos': 0.23119864},
#  48: {'roberta_neg': 0.17214364,
#   'roberta_neu': 0.61910814,
#   'roberta_pos': 0.20874825},
#  49: {'roberta_neg': 0.041756164,
#   'roberta_neu': 0.7099346,
#   'roberta_pos': 0.24830922},
#  50: {'roberta_neg': 0.1742677,
#   'roberta_neu': 0.4752075,
#   'roberta_pos': 0.3505248},
#  51: {'roberta_neg': 0.010513337,
#   'roberta_neu': 0.43798456,
#   'roberta_pos': 0.55150205},
#  52: {'roberta_neg': 0.1635611,
#   'roberta_neu': 0.67321557,
#   'roberta_pos': 0.16322337},
#  53: {'roberta_neg': 0.023055945,
#   'roberta_neu': 0.8920645,
#   'roberta_pos': 0.08487947},
#  54: {'roberta_neg': 0.0022337819,
#   'roberta_neu': 0.03499238,
#   'roberta_pos': 0.96277386},
#  55: {'roberta_neg': 0.017227879,
#   'roberta_neu': 0.35413817,
#   'roberta_pos': 0.628634},
#  56: {'roberta_neg': 0.6162712,
#   'roberta_neu': 0.35441694,
#   'roberta_pos': 0.02931193},
#  57: {'roberta_neg': 0.8762957,
#   'roberta_neu': 0.114643045,
#   'roberta_pos': 0.00906118},
#  58: {'roberta_neg': 0.49544856,
#   'roberta_neu': 0.45831588,
#   'roberta_pos': 0.046235617},
#  59: {'roberta_neg': 0.019897852,
#   'roberta_neu': 0.73121583,
#   'roberta_pos': 0.2488863},
#  60: {'roberta_neg': 0.1708017,
#   'roberta_neu': 0.7483398,
#   'roberta_pos': 0.080858506},
#  61: {'roberta_neg': 0.72514564,
#   'roberta_neu': 0.23887691,
#   'roberta_pos': 0.035977386},
#  62: {'roberta_neg': 0.67065424,
#   'roberta_neu': 0.31232628,
#   'roberta_pos': 0.017019458},
#  63: {'roberta_neg': 0.63941056,
#   'roberta_neu': 0.34905592,
#   'roberta_pos': 0.011533507},
#  64: {'roberta_neg': 0.11356569,
#   'roberta_neu': 0.79244685,
#   'roberta_pos': 0.0939874},
#  65: {'roberta_neg': 0.42924243,
#   'roberta_neu': 0.5397286,
#   'roberta_pos': 0.031028993},
#  66: {'roberta_neg': 0.016752817,
#   'roberta_neu': 0.5575383,
#   'roberta_pos': 0.42570895},
#  67: {'roberta_neg': 0.0077387397,
#   'roberta_neu': 0.101538435,
#   'roberta_pos': 0.89072275},
#  68: {'roberta_neg': 0.32516462,
#   'roberta_neu': 0.6298321,
#   'roberta_pos': 0.04500329},
#  69: {'roberta_neg': 0.29362598,
#   'roberta_neu': 0.47883895,
#   'roberta_pos': 0.22753505},
#  70: {'roberta_neg': 0.04188292,
#   'roberta_neu': 0.38241354,
#   'roberta_pos': 0.5757035},
#  71: {'roberta_neg': 0.64778674,
#   'roberta_neu': 0.31895402,
#   'roberta_pos': 0.033259243},
#  72: {'roberta_neg': 0.06285591,
#   'roberta_neu': 0.8720761,
#   'roberta_pos': 0.065067954},
#  73: {'roberta_neg': 0.4120071,
#   'roberta_neu': 0.565465,
#   'roberta_pos': 0.022527914},
#  74: {'roberta_neg': 0.6379486,
#   'roberta_neu': 0.32599822,
#   'roberta_pos': 0.036053184},
#  75: {'roberta_neg': 0.39982685,
#   'roberta_neu': 0.54716545,
#   'roberta_pos': 0.05300776},
#  76: {'roberta_neg': 0.8890345,
#   'roberta_neu': 0.1013874,
#   'roberta_pos': 0.009578063},
#  77: {'roberta_neg': 0.73995817,
#   'roberta_neu': 0.2424083,
#   'roberta_pos': 0.017633537},
#  78: {'roberta_neg': 0.018685738,
#   'roberta_neu': 0.40498403,
#   'roberta_pos': 0.57633024},
#  79: {'roberta_neg': 0.15251778,
#   'roberta_neu': 0.76023096,
#   'roberta_pos': 0.08725127},
#  80: {'roberta_neg': 0.29500285,
#   'roberta_neu': 0.6656968,
#   'roberta_pos': 0.039300315},
#  81: {'roberta_neg': 0.8982339,
#   'roberta_neu': 0.093445666,
#   'roberta_pos': 0.00832043},
#  82: {'roberta_neg': 0.2561985,
#   'roberta_neu': 0.6832672,
#   'roberta_pos': 0.06053433},
#  83: {'roberta_neg': 0.8072771,
#   'roberta_neu': 0.1803937,
#   'roberta_pos': 0.012329242},
#  84: {'roberta_neg': 0.9430763,
#   'roberta_neu': 0.052132215,
#   'roberta_pos': 0.00479144},
#  85: {'roberta_neg': 0.15955606,
#   'roberta_neu': 0.74041116,
#   'roberta_pos': 0.10003279},
#  86: {'roberta_neg': 0.6854475,
#   'roberta_neu': 0.2913345,
#   'roberta_pos': 0.023217974},
#  87: {'roberta_neg': 0.34240916,
#   'roberta_neu': 0.6367504,
#   'roberta_pos': 0.020840477},
#  88: {'roberta_neg': 0.35715282,
#   'roberta_neu': 0.5805682,
#   'roberta_pos': 0.062278956},
#  89: {'roberta_neg': 0.017453332,
#   'roberta_neu': 0.55985284,
#   'roberta_pos': 0.42269382},
#  90: {'roberta_neg': 0.43207067,
#   'roberta_neu': 0.5396085,
#   'roberta_pos': 0.028320836},
#  91: {'roberta_neg': 0.025648555,
#   'roberta_neu': 0.67062503,
#   'roberta_pos': 0.30372638},
#  92: {'roberta_neg': 0.89188355,
#   'roberta_neu': 0.09860663,
#   'roberta_pos': 0.009509882},
#  93: {'roberta_neg': 0.09240756,
#   'roberta_neu': 0.7377951,
#   'roberta_pos': 0.1697973},
#  94: {'roberta_neg': 0.20813695,
#   'roberta_neu': 0.7429185,
#   'roberta_pos': 0.04894458},
#  95: {'roberta_neg': 0.08699762,
#   'roberta_neu': 0.7618155,
#   'roberta_pos': 0.15118691},
#  96: {'roberta_neg': 0.07308769,
#   'roberta_neu': 0.85923654,
#   'roberta_pos': 0.067675754},
#  97: {'roberta_neg': 0.43829727,
#   'roberta_neu': 0.5394892,
#   'roberta_pos': 0.022213567},
#  98: {'roberta_neg': 0.20646778,
#   'roberta_neu': 0.7261369,
#   'roberta_pos': 0.06739534},
#  99: {'roberta_neg': 0.2481215,
#   'roberta_neu': 0.70705837,
#   'roberta_pos': 0.044820096},
#  100: {'roberta_neg': 0.97896534,
#   'roberta_neu': 0.018781941,
#   'roberta_pos': 0.002252709},
#  101: {'roberta_neg': 0.029047683,
#   'roberta_neu': 0.6086061,
#   'roberta_pos': 0.36234617},
#  102: {'roberta_neg': 0.3922692,
#   'roberta_neu': 0.55857795,
#   'roberta_pos': 0.049152855},
#  103: {'roberta_neg': 0.8985314,
#   'roberta_neu': 0.09304102,
#   'roberta_pos': 0.008427585},
#  104: {'roberta_neg': 0.24013059,
#   'roberta_neu': 0.6437286,
#   'roberta_pos': 0.116140775},
#  105: {'roberta_neg': 0.06335107,
#   'roberta_neu': 0.88055617,
#   'roberta_pos': 0.05609272},
#  106: {'roberta_neg': 0.21168657,
#   'roberta_neu': 0.75145715,
#   'roberta_pos': 0.036856253},
#  107: {'roberta_neg': 0.2699134,
#   'roberta_neu': 0.6728143,
#   'roberta_pos': 0.05727228},
#  108: {'roberta_neg': 0.06389335,
#   'roberta_neu': 0.81820893,
#   'roberta_pos': 0.11789769},
#  109: {'roberta_neg': 0.20959067,
#   'roberta_neu': 0.7584024,
#   'roberta_pos': 0.03200693},
#  110: {'roberta_neg': 0.43367934,
#   'roberta_neu': 0.5242721,
#   'roberta_pos': 0.04204853},
#  111: {'roberta_neg': 0.22768314,
#   'roberta_neu': 0.59571075,
#   'roberta_pos': 0.17660609},
#  112: {'roberta_neg': 0.45353064,
#   'roberta_neu': 0.52636683,
#   'roberta_pos': 0.02010249},
#  113: {'roberta_neg': 0.24873798,
#   'roberta_neu': 0.628737,
#   'roberta_pos': 0.12252502},
#  114: {'roberta_neg': 0.41691813,
#   'roberta_neu': 0.5055777,
#   'roberta_pos': 0.0775042},
#  115: {'roberta_neg': 0.046201427,
#   'roberta_neu': 0.8229766,
#   'roberta_pos': 0.13082188},
#  116: {'roberta_neg': 0.1099028,
#   'roberta_neu': 0.8403981,
#   'roberta_pos': 0.049699105},
#  117: {'roberta_neg': 0.005853538,
#   'roberta_neu': 0.3887569,
#   'roberta_pos': 0.60538954},
#  118: {'roberta_neg': 0.5029629,
#   'roberta_neu': 0.43912178,
#   'roberta_pos': 0.057915337},
#  119: {'roberta_neg': 0.19564891,
#   'roberta_neu': 0.747034,
#   'roberta_pos': 0.05731706},
#  120: {'roberta_neg': 0.15315479,
#   'roberta_neu': 0.8150333,
#   'roberta_pos': 0.03181191},
#  121: {'roberta_neg': 0.8585313,
#   'roberta_neu': 0.12100017,
#   'roberta_pos': 0.020468583},
#  122: {'roberta_neg': 0.024011403,
#   'roberta_neu': 0.33183533,
#   'roberta_pos': 0.64415324},
#  123: {'roberta_neg': 0.11748836,
#   'roberta_neu': 0.79972285,
#   'roberta_pos': 0.08278876},
#  124: {'roberta_neg': 0.059303507,
#   'roberta_neu': 0.8634446,
#   'roberta_pos': 0.07725193},
#  125: {'roberta_neg': 0.09760431,
#   'roberta_neu': 0.79911804,
#   'roberta_pos': 0.10327766},
#  126: {'roberta_neg': 0.1957597,
#   'roberta_neu': 0.6685542,
#   'roberta_pos': 0.13568608},
#  127: {'roberta_neg': 0.18178919,
#   'roberta_neu': 0.61551064,
#   'roberta_pos': 0.20270015},
#  128: {'roberta_neg': 0.063339554,
#   'roberta_neu': 0.8528769,
#   'roberta_pos': 0.083783604},
#  129: {'roberta_neg': 0.14860392,
#   'roberta_neu': 0.7752984,
#   'roberta_pos': 0.07609767},
#  130: {'roberta_neg': 0.14355288,
#   'roberta_neu': 0.65876603,
#   'roberta_pos': 0.19768105},
#  131: {'roberta_neg': 0.14209302,
#   'roberta_neu': 0.7906581,
#   'roberta_pos': 0.06724882},
#  132: {'roberta_neg': 0.08194344,
#   'roberta_neu': 0.88906705,
#   'roberta_pos': 0.028989557},
#  133: {'roberta_neg': 0.12563536,
#   'roberta_neu': 0.7953865,
#   'roberta_pos': 0.078978114},
#  134: {'roberta_neg': 0.020392923,
#   'roberta_neu': 0.6206551,
#   'roberta_pos': 0.35895196},
#  135: {'roberta_neg': 0.06001302,
#   'roberta_neu': 0.700954,
#   'roberta_pos': 0.23903292},
#  136: {'roberta_neg': 0.061419636,
#   'roberta_neu': 0.8492714,
#   'roberta_pos': 0.08930898},
#  137: {'roberta_neg': 0.34828344,
#   'roberta_neu': 0.6337869,
#   'roberta_pos': 0.01792965},
#  138: {'roberta_neg': 0.03351789,
#   'roberta_neu': 0.74176455,
#   'roberta_pos': 0.22471748},
#  139: {'roberta_neg': 0.341937,
#   'roberta_neu': 0.59524685,
#   'roberta_pos': 0.06281614},
#  140: {'roberta_neg': 0.010540291,
#   'roberta_neu': 0.8446957,
#   'roberta_pos': 0.14476396},
#  141: {'roberta_neg': 0.5677804,
#   'roberta_neu': 0.40604833,
#   'roberta_pos': 0.026171234},
#  142: {'roberta_neg': 0.050197624,
#   'roberta_neu': 0.26206204,
#   'roberta_pos': 0.6877404},
#  143: {'roberta_neg': 0.1743798,
#   'roberta_neu': 0.7467106,
#   'roberta_pos': 0.07890962},
#  144: {'roberta_neg': 0.8159737,
#   'roberta_neu': 0.17013316,
#   'roberta_pos': 0.013893092},
#  145: {'roberta_neg': 0.09126034,
#   'roberta_neu': 0.62706065,
#   'roberta_pos': 0.28167906},
#  146: {'roberta_neg': 0.53400826,
#   'roberta_neu': 0.42864943,
#   'roberta_pos': 0.03734229},
#  147: {'roberta_neg': 0.019582521,
#   'roberta_neu': 0.714126,
#   'roberta_pos': 0.26629144},
#  148: {'roberta_neg': 0.10309423,
#   'roberta_neu': 0.84497404,
#   'roberta_pos': 0.051931746},
#  149: {'roberta_neg': 0.4514031,
#   'roberta_neu': 0.47564045,
#   'roberta_pos': 0.07295647},
#  150: {'roberta_neg': 0.06820788,
#   'roberta_neu': 0.51960254,
#   'roberta_pos': 0.4121896},
#  151: {'roberta_neg': 0.01578404,
#   'roberta_neu': 0.78622884,
#   'roberta_pos': 0.19798706},
#  152: {'roberta_neg': 0.005610638,
#   'roberta_neu': 0.31269294,
#   'roberta_pos': 0.6816964},
#  153: {'roberta_neg': 0.4396161,
#   'roberta_neu': 0.36478797,
#   'roberta_pos': 0.19559593},
#  154: {'roberta_neg': 0.11581142,
#   'roberta_neu': 0.77757025,
#   'roberta_pos': 0.106618375},
#  155: {'roberta_neg': 0.6119257,
#   'roberta_neu': 0.35075107,
#   'roberta_pos': 0.037323203},
#  156: {'roberta_neg': 0.09994684,
#   'roberta_neu': 0.5684501,
#   'roberta_pos': 0.33160308},
#  157: {'roberta_neg': 0.026580578,
#   'roberta_neu': 0.6242087,
#   'roberta_pos': 0.3492107},
#  158: {'roberta_neg': 0.27573833,
#   'roberta_neu': 0.68861985,
#   'roberta_pos': 0.035641853},
#  159: {'roberta_neg': 0.668068,
#   'roberta_neu': 0.3055772,
#   'roberta_pos': 0.026354777},
#  160: {'roberta_neg': 0.07115874,
#   'roberta_neu': 0.7263902,
#   'roberta_pos': 0.20245108},
#  161: {'roberta_neg': 0.0048516584,
#   'roberta_neu': 0.08032757,
#   'roberta_pos': 0.91482073},
#  162: {'roberta_neg': 0.009564262,
#   'roberta_neu': 0.09142038,
#   'roberta_pos': 0.89901537},
#  163: {'roberta_neg': 0.12379257,
#   'roberta_neu': 0.82072794,
#   'roberta_pos': 0.055479452},
#  164: {'roberta_neg': 0.10677654,
#   'roberta_neu': 0.6129177,
#   'roberta_pos': 0.28030574},
#  165: {'roberta_neg': 0.1901459,
#   'roberta_neu': 0.7625606,
#   'roberta_pos': 0.047293548},
#  166: {'roberta_neg': 0.39309967,
#   'roberta_neu': 0.5835362,
#   'roberta_pos': 0.023364108},
#  167: {'roberta_neg': 0.13160092,
#   'roberta_neu': 0.8149031,
#   'roberta_pos': 0.053496055},
#  168: {'roberta_neg': 0.58949405,
#   'roberta_neu': 0.38919273,
#   'roberta_pos': 0.02131316},
#  169: {'roberta_neg': 0.4431901,
#   'roberta_neu': 0.48812446,
#   'roberta_pos': 0.06868538},
#  170: {'roberta_neg': 0.6572365,
#   'roberta_neu': 0.32830626,
#   'roberta_pos': 0.014457217},
#  171: {'roberta_neg': 0.3689765,
#   'roberta_neu': 0.6047431,
#   'roberta_pos': 0.026280418},
#  172: {'roberta_neg': 0.35696813,
#   'roberta_neu': 0.60621023,
#   'roberta_pos': 0.036821634},
#  173: {'roberta_neg': 0.4415484,
#   'roberta_neu': 0.53806573,
#   'roberta_pos': 0.020385863},
#  174: {'roberta_neg': 0.2748762,
#   'roberta_neu': 0.58656806,
#   'roberta_pos': 0.13855572}}

# %%
# necessary packages
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax

df = pd.read_csv("topic_18_documents.csv")
df = df.Document.tolist()

# model, tokenizer and so on are located in the following repo
model_path = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(model_path)
config = AutoConfig.from_pretrained(model_path)
roberta_model = AutoModelForSequenceClassification.from_pretrained(model_path)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df = pd.read_csv("topic_19_documents.csv")
df = df[["Document"]]


# model, tokenizer and so on are located in the following repo
model_path = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(model_path)
config = AutoConfig.from_pretrained(model_path)
roberta_model = AutoModelForSequenceClassification.from_pretrained(model_path)

# a function that takes text and model to calculate probability of each sentiment
def sentiment_analyzer(text, model):
    encoded_input = tokenizer(text, return_tensors="pt")
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = np.round(softmax(scores), 2)
    scores_dict = {"neg": scores[0], "neu": scores[1], "pos": scores[2]}
    return scores_dict

# apply the roberta function
df["probabilities"] = df["Document"].apply(sentiment_analyzer, model=roberta_model)

# since roberta model returned probability of each sentiment as a dictionary
# let's convert each probaility into separate column
probabilities = df["probabilities"].apply(pd.Series)
df = df.join(probabilities)
df = df.drop("probabilities", axis=1)

# now calculate the polarity for each text by:
# first multiplying each probability to its weights (-1=> negative, 0=>neutral and +1=>positive)
# then sum the values and pass through Tanh function to scale values from -1 up to +1
# finally we can assign labels for each text, depending on the polarity, e.g. -1.0 until -0.25 negavite
polarity_weights = torch.tensor([-1, 0, 1])
probs = torch.tensor(df[["neg", "neu", "pos"]].values)
polarity = polarity_weights * probs
polarity = polarity.sum(dim=-1)
polarity_scaled = nn.Tanh()(polarity)
df["Topic"] = "topic_19"
df["roberta_polarity"] = polarity_scaled.numpy()
df["roberta_sentiment"] = pd.cut(df["roberta_polarity"],
    bins=[-1.0, -0.25, 0.25, 1.0],labels=["Negative", "Neutral", "Positive"],)
df = df.drop(["neu", "neg", "pos"], axis=1)
df.head()
df.to_csv('SentiTopic19.csv', index=False)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pandas as pd

# 0 1 2 5 _ 3 11 13 _ 8 9 10 15 18 _ 4 7 12 17 19 _ 6 14 16

# List of CSV file paths
csv_files = ["SentiTopic8.csv","SentiTopic10.csv"]

# Read each file into a DataFrame
dataframes = [pd.read_csv(file) for file in csv_files]

# Combine DataFrames vertically, ignoring row indices
merged_df = pd.concat(dataframes, ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv("Senti_Theme7.csv", index=False)

# %%
import seaborn as sns

import pandas as pd
df = pd.read_csv("Senti_merged_data.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", multiple="stack")
# sns.displot(df, x="roberta_polarity", kind="kde", bw_adjust=0.5)

# %%
import seaborn as sns

import pandas as pd
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", multiple="stack", palette=sns.color_palette("bright"))
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\4183661603.py:6: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", multiple="stack", palette=sns.color_palette("bright"))

# %%
import seaborn as sns

import pandas as pd
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, palette=sns.color_palette("bright"), height=10, aspect=1.5)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\1495531842.py:6: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, palette=sns.color_palette("bright"), height=10, aspect=1.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_minus0and1.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("SentiPlot_minus0and1.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\1865593951.py:7: UserWarning:
# The palette list has fewer values (10) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_0_1_2_5.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("Senti_merged_data_0_1_2_5.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\1407564564.py:7: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_3_11_13.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("Senti_merged_data_3_11_13.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\692891092.py:7: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_4_7_12_17_19.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("Senti_merged_data_4_7_12_17_19.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\4083430670.py:7: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_6_14_16.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("Senti_merged_data_6_14_16.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\1672605854.py:7: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster")
# sns.set(style="whitegrid")
df = pd.read_csv("Senti_merged_data_8_9_10_15_18.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))
plt.savefig("Senti_merged_data_8_9_10_15_18.png", dpi=300)
# Out:
# C:\Users\Sia\AppData\Local\Temp\ipykernel_8600\3929698711.py:7: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=True, height=10, aspect=1.5, palette=sns.color_palette("bright"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_context("poster", font_scale=2, rc={"lines.linewidth": 5})
# sns.set(style="whitegrid")
df = pd.read_csv("SentiTopic19.csv")
sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=False, height=10, aspect=1)
plt.savefig("SentiTopic19.png", dpi=300)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_context("poster", font_scale=2, rc={"lines.linewidth": 5})
# sns.set(style="whitegrid")

df = pd.read_csv("Senti_Theme7.csv")

# Create the Seaborn plot
g = sns.displot(df, x="roberta_polarity", hue="Topic", kind="kde", fill=False, height=10, aspect=1)

# Access the Matplotlib axis
ax = g.fig.axes[0]  # Get the first axis from the figure

ax.set_xlabel("roBERTa Polarity")

# Set axis limits (optional)
ax.set_ylim(0, 1)

# Save the plot
plt.savefig("Senti_Theme7.png", dpi=300)
